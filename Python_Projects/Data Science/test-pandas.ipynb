# %%
import pandas as pd

df = pd.read_csv('pokemon_data.csv')

# print(df.tail(3))

# %%
##Reading Headers
df.columns

##Read Each Column
df[['Name','HP']][0:5]

##Read Each Row
# df.iloc[1:4]
# for index, row in df.iterrows():
#     print(index,row['Name'])
df.loc[df['Type 1'] == "Fire"]

##Read a specific location (r,c)
# df.iloc[2,1] ##This will return a specific cell location first parameter is the row, second param is column
# Out:
#        #                       Name Type 1    Type 2  Total   HP  Attack  \
# 4      4                 Charmander   Fire       NaN    309   39      52
# 5      5                 Charmeleon   Fire       NaN    405   58      64
# 6      6                  Charizard   Fire    Flying    534   78      84
# 7      6  CharizardMega Charizard X   Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y   Fire    Flying    634   78     104
# 42    37                     Vulpix   Fire       NaN    299   38      41
# 43    38                  Ninetales   Fire       NaN    505   73      76
# 63    58                  Growlithe   Fire       NaN    350   55      70
# 64    59                   Arcanine   Fire       NaN    555   90     110
# 83    77                     Ponyta   Fire       NaN    410   50      85
# 84    78                   Rapidash   Fire       NaN    500   65     100
# 135  126                     Magmar   Fire       NaN    495   65      95
# ...

# %%
#Allows you to get a quick metrics about the content. (mean, count, std, min, max, percentials)
df.describe()

df.sort_values(['Type 1','HP'] ,ascending=[True,False])
# Out:
#        #                     Name Type 1    Type 2  Total  HP  Attack  \
# 520  469                  Yanmega    Bug    Flying    515  86      76
# 698  637                Volcarona    Bug      Fire    550  85      60
# 231  214                Heracross    Bug  Fighting    500  80     125
# 232  214  HeracrossMega Heracross    Bug  Fighting    600  80     185
# 678  617                 Accelgor    Bug       NaN    495  80      70
# ..   ...                      ...    ...       ...    ...  ..     ...
# 106   98                   Krabby  Water       NaN    325  30     105
# 125  116                   Horsea  Water       NaN    295  30      40
# 129  120                   Staryu  Water       NaN    340  30      45
# 139  129                 Magikarp  Water       NaN    200  20      10
# 381  349                   Feebas  Water       NaN    200  20      15
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 520       86      116       56     95           4      False
# ...

# %%
#Making changes to the data
# df['total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

# df = df.drop(columns=['Total'])

df['Total'] = df.iloc[:, 4:10].sum(axis=1)

cols = list(df.columns)
df = df[cols[0:4] + [cols[-1]] + cols[4:12]]

df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
#Exporting out to a new file
# df.to_csv('new_file.csv', index=False) #CSV Format

# df.to_excel('new_file.xlsx', index=False) #Excel Format

# df.to_csv('new_file.txt',index=False, sep='\t') #Tab Deliminated txt file

# %%
# df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] =='Poison')] #AND Condition
# df.loc[(df['Type 1'] == 'Grass') | (df['Type 2'] =='Poison')] #OR Condition

new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] =='Poison') & (df['HP'] > 70)]

# new_df.reset_index() #To get a new set of index which are with the new filtered list use this function
new_df.reset_index(drop=True) #To remove old index column use this param
# Out:
#      #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0    3               Venusaur  Grass  Poison    525   80      82       83
# 1    3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 2   45              Vileplume  Grass  Poison    490   75      80       85
# 3   71             Victreebel  Grass  Poison    490   80     105       65
# 4  591              Amoonguss  Grass  Poison    464  114      85       70
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0      100      100     80           1      False
# 1      122      120     80           1      False
# 2      110       90     50           1      False
# 3      100       70     70           1      False
# 4       85       80     30           5      False
